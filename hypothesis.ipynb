# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# https://www.youtube.com/watch?v=0oc49DyA3hU

# import numpy and pandas
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %%
# Your code here:
data = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# change format to handle easier
cols = []
for column in range(len(data.columns)):
    cols.append(data.columns[column].lower().replace(' ', '_'))
data.columns = cols

# %%
data
# Out:
#                          name                 job_titles        department  \
# 0      ADRIANO,  RACQUEL ANNE                  PARAMEDIC              FIRE
# 1           AFFANEH,  MAHIR A             POLICE OFFICER            POLICE
# 2           AFOENYI,  PHYLLIS  TITLE V PROGRAM TRAINEE I  FAMILY & SUPPORT
# 3             AGAR,  BULENT B        DEPUTY COMMISSIONER       WATER MGMNT
# 4             AGEE,  LAWRENCE             POLICE OFFICER            POLICE
# ...                       ...                        ...               ...
# 33697      ZYLINSKA,  KLAUDIA             POLICE OFFICER            POLICE
# 33698      ZYMANTAS,  LAURA C             POLICE OFFICER            POLICE
# 33699       ZYMANTAS,  MARK E             POLICE OFFICER            POLICE
# 33700     ZYRKOWSKI,  CARLO E             POLICE OFFICER            POLICE
# 33701     ZYSKOWSKI,  DARIUSZ    CHIEF DATA BASE ANALYST              DAIS
#
# ...

# %%
# Your code here:
data['salary_or_hourly'].head()
# Out:
# 0    Salary
# 1    Salary
# 2    Hourly
# 3    Salary
# 4    Salary
# Name: salary_or_hourly, dtype: object

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
data.isnull().sum()
# Out:
# name                     0
# job_titles               0
# department               0
# full_or_part-time        0
# salary_or_hourly         0
# typical_hours        25528
# annual_salary         8174
# hourly_rate          25528
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
data['salary_or_hourly'].value_counts(dropna=False)
# Out:
# Salary    25528
# Hourly     8174
# Name: salary_or_hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
data['department'].value_counts(dropna=False)
# Out:
# POLICE                 13848
# FIRE                    4627
# STREETS & SAN           2175
# WATER MGMNT             1914
# AVIATION                1856
# OEMC                    1737
# TRANSPORTN              1113
# PUBLIC LIBRARY          1088
# DAIS                    1033
# FAMILY & SUPPORT         656
# FINANCE                  544
# HEALTH                   467
# LAW                      398
# CITY COUNCIL             362
# BUILDINGS                258
# PUBLIC SAFETY ADMIN      244
# BUSINESS AFFAIRS         167
# HOUSING & ECON DEV       154
# COPA                     123
# BOARD OF ELECTION        111
# MAYOR'S OFFICE           104
# INSPECTOR GEN             95
# CITY CLERK                88
# PROCUREMENT               84
# HUMAN RESOURCES           75
# ANIMAL CONTRL             75
# CULTURAL AFFAIRS          74
# HOUSING                   66
# BUDGET & MGMT             44
# ADMIN HEARNG              38
# DISABILITIES              28
# TREASURER                 28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
import scipy.stats as st
from scipy.stats import ttest_1samp

# %%
hourly_workers
# Out:
#                          name                      job_titles  \
# 2           AFOENYI,  PHYLLIS       TITLE V PROGRAM TRAINEE I
# 5           AGNEW,  ANTONIO E              MOTOR TRUCK DRIVER
# 15         AGSALUD,  FERNAN S              SANITATION LABORER
# 16     AGSALUD JR,  JUANITO S              SANITATION LABORER
# 21            AGUAYO,  LUIS M            LABORER - APPRENTICE
# ...                       ...                             ...
# 33676         ZUNIGA,  THOMAS           GENERAL LABORER - DSS
# 33678             ZUNO,  ERIK            CONSTRUCTION LABORER
# 33681      ZURAWSKI,  JEFFREY  FRM OF MACHINISTS - AUTOMOTIVE
# 33684         ZUREK,  FRANCIS             ELECTRICAL MECHANIC
# 33688      ZWARYCZ,  THOMAS J              MOTOR TRUCK DRIVER
#
#                 department full_or_part-time salary_or_hourly  typical_hours  \
# 2         FAMILY & SUPPORT                 P           Hourly           20.0
# ...

# %%
# Your code here:
hourly_workers = data[data['salary_or_hourly']=='Hourly']
hourly_rate = hourly_workers['hourly_rate']

stat, pval = ttest_1samp(hourly_rate, 30)

print('mean is: ', hourly_rate.mean())
print('stat is:  ', stat) 
print('pvalue for the two-tailed test is: ', pval)

# P > 0.05 is the probability that the null hypothesis is true;  A statistically significant test result (P ≤ 0.05) 
# means that the test hypothesis is false or should be rejected; therefore we can determine that the hourly rate is
# not significantly close to $30.
# Out:
# mean is:  34.58644971862046
# stat is:   31.211500329216044
# pvalue for the two-tailed test is:  3.825475847673794e-202

# %%
hourly_workers['hourly_rate'].mean()
# Out:
# 34.58644971862046

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
police_force = data[data['department']=='POLICE']
police_wage = police_force['annual_salary'].dropna()

print('mean is: ', police_wage.mean())
stat, pval = ttest_1samp(police_wage, 86000)

print('stat is:  ', stat) 
print('pvalue for the two-tailed test is: ', pval/2)
# Out:
# mean is:  88834.11892361111
# stat is:   18.51748561981861
# pvalue for the two-tailed test is:  6.119566952121482e-76

# %%
police_wage.describe()
# Out:
# count     13824.000000
# mean      88834.118924
# std       17995.044146
# min       42960.000000
# 25%       77520.000000
# 50%       90024.000000
# 75%       96060.000000
# max      260004.000000
# Name: annual_salary, dtype: float64

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:

data_crosstab = pd.crosstab(data['department'], data['salary_or_hourly'], margins=False)
print(data_crosstab.max().head(1))
print('-----------------------------')
print(data_crosstab.idxmax(axis=0))
print('-----------------------------')
print('Hourly max value is: ', data_crosstab['Hourly'].max())
print('-----------------------------')
print('Salary max value is: ', data_crosstab['Salary'].max())
print('-----------------------------')
display(data_crosstab)
# Out:
# salary_or_hourly
# Hourly    1846
# dtype: int64
# -----------------------------
# salary_or_hourly
# Hourly    STREETS & SAN
# Salary           POLICE
# dtype: object
# -----------------------------
# Hourly max value is:  1846
# -----------------------------
# Salary max value is:  13824
# -----------------------------
# salary_or_hourly     Hourly  Salary
# department
# ADMIN HEARNG              0      38
# ANIMAL CONTRL            12      63
# AVIATION               1214     642
# BOARD OF ELECTION         0     111
# BOARD OF ETHICS           0       8
# BUDGET & MGMT             2      42
# BUILDINGS                 0     258
# BUSINESS AFFAIRS          7     160
# CITY CLERK                0      88
# CITY COUNCIL             74     288
# COPA                      0     123
# CULTURAL AFFAIRS         10      64
# DAIS                    745     288
# DISABILITIES              1      27
# FAMILY & SUPPORT        357     299
# FINANCE                  45     499
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:

police_force = data[data['department']=='POLICE']
police_wage_hourly = police_force[police_force['salary_or_hourly']=='Hourly']
hour_police_wage = police_wage_hourly['hourly_rate']

print('mean is: ', hour_police_wage.mean())
stat, pval = ttest_1samp(hour_police_wage, 35)

print('stat is:  ', stat) 
print('pvalue for the two-tailed test is: ', pval)

#The wage is considerably less than $35
# Out:
# mean is:  12.270000000000001
# stat is:   -121.04171744278607
# pvalue for the two-tailed test is:  9.145331369283761e-34

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
hourly_workers = hourly_workers.reset_index(drop=True)
hourly_workers
# Out:
#                         name                      job_titles  \
# 0          AFOENYI,  PHYLLIS       TITLE V PROGRAM TRAINEE I
# 1          AGNEW,  ANTONIO E              MOTOR TRUCK DRIVER
# 2         AGSALUD,  FERNAN S              SANITATION LABORER
# 3     AGSALUD JR,  JUANITO S              SANITATION LABORER
# 4            AGUAYO,  LUIS M            LABORER - APPRENTICE
# ...                      ...                             ...
# 8169         ZUNIGA,  THOMAS           GENERAL LABORER - DSS
# 8170             ZUNO,  ERIK            CONSTRUCTION LABORER
# 8171      ZURAWSKI,  JEFFREY  FRM OF MACHINISTS - AUTOMOTIVE
# 8172         ZUREK,  FRANCIS             ELECTRICAL MECHANIC
# 8173      ZWARYCZ,  THOMAS J              MOTOR TRUCK DRIVER
#
#                department full_or_part-time salary_or_hourly  typical_hours  \
# 0        FAMILY & SUPPORT                 P           Hourly           20.0
# 1                AVIATION                 F           Hourly           40.0
# ...

# %%
# Your code here:

# mean of the sample for the location parameter & standard erros for the scale

import scipy.stats

confidence_level = 0.95

hourly_rate = hourly_workers["hourly_rate"]

degrees_freedom = len(hourly_rate) - 1 
sample_mean = np.mean(hourly_rate)     # we use the standard error of the sample 

sample_standard_error = scipy.stats.sem(hourly_rate) # sem = standard error of the mean = std(mean)/sqrt(samplesize)

confidence_interval = scipy.stats.t.interval(confidence_level, 
                                             degrees_freedom, 
                                             sample_mean, 
                                             sample_standard_error)

print( 'confidence interval is ', confidence_interval, '.' )
# Out:
# confidence interval is  (34.29839539204361, 34.874504045197305) .

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
police_wage
# Out:
# 1         93354.0
# 4         90024.0
# 6        111444.0
# 7        103932.0
# 9         95736.0
#            ...
# 33696     80016.0
# 33697     72510.0
# 33698     76266.0
# 33699     90024.0
# 33700     93354.0
# Name: annual_salary, Length: 13824, dtype: float64

# %%
# Your code here:

confidence_level = 0.95 
degrees_freedom = len(police_wage)
sample_mean = np.mean(police_wage) #reuse earlier variable that defined this 'salaried police'

sample_standard_error = scipy.stats.sem(police_wage) 
confidence_interval = scipy.stats.t.interval(confidence_level,
                                             degrees_freedom,
                                             sample_mean,
                                             sample_standard_error)

print('confidence interval is ', confidence_interval)
# Out:
# confidence interval is  (88534.11829048868, 89134.11955673354)

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
